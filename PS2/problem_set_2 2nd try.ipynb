# %% [markdown]
# # Problem set 2: Finding the Walras equilibrium in a multi-agent economy

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Tasks

# %% [markdown]
# ## Drawing random numbers

# %% [markdown]
# Replace the missing lines in the code below to get the same output as in the answer.

# %%
import numpy as np
np.random.seed(1986)
# missing line
state = np.random.get_state()
for i in range(3):
    # missing line
    np.random.set_state(state)
    for j in range(2):
        x = np.random.uniform()
        print(f'({i},{j}): x = {x:.3f}')
# Out:
# (0,0): x = 0.569
# (0,1): x = 0.077
# (1,0): x = 0.569
# (1,1): x = 0.077
# (2,0): x = 0.569
# (2,1): x = 0.077

# %% [markdown]
# **Answer:**

# %% [markdown]
# See A1.py

# %% [markdown]
# ## Find the expectated value

# %% [markdown]
# Find the expected value and the expected variance
#
# $$
# \mathbb{E}[g(x)] \approx \frac{1}{N}\sum_{i=1}^{N} g(x_i)
# $$
# $$
# \mathbb{VAR}[g(x)] \approx \frac{1}{N}\sum_{i=1}^{N} \left( g(x_i) - \frac{1}{N}\sum_{i=1}^{N} g(x_i) \right)^2
# $$
#
# where $ x_i \sim \mathcal{N}(0,\sigma) $ and
#
# $$
# g(x,\omega)=\begin{cases}
# x & \text{if }x\in[-\omega,\omega]\\
# -\omega & \text{if }x<-\omega\\
# \omega & \text{if }x>\omega
# \end{cases}
# $$

# %%
sigma = 3.14
omega = 2
N = 10000
np.random.seed(1986)

#1) Draw random numbers
x = np.random.normal(loc=0, scale=sigma, size = N)

#2) Define g-function

def g(x,omega):
    y=x.copy() 
    #vi sætter y lig med x, men hvor y er en kopi,
    #så vi ikke ændrer på x, når vi ændrer på y.
    y[x<-omega] = -omega
    #hvis x er mindre end omega, så ændrer vi værdien fra x til minus omega
    y[x>omega] = omega
    #hvis x er større end omega, så ændrer vi værdien fra x til omega

    return y
    #returnerer værdien af g

#3) calculate mean of g
mean_g = np.mean(g(x,omega))
#bruger numpy funktionen mean til at regne gennemsnittet af g.

#4) calculate var of g

var_g = np.var(g(x,omega))
#bruger numpy funktionen var til at regne variansen af g.

var_brute = np.mean((g(x,omega)-np.mean(g(x,omega)))**2)
#regner det vha. formlen

# %%
print(type(x))
print(mean_g)
print(var_g)
print(var_brute)
# Out:
# <class 'numpy.ndarray'>
# -0.0026419419466646686
# 2.6980407418768872
# 2.6980407418768872

# %% [markdown]
# **Answer:**

# %% [markdown]
# See A2.py

# %% [markdown]
# ## Interactive histogram

# %% [markdown]
# **First task:** Consider the code below. Fill in the missing lines so the figure is plotted.

# %%
# a. import
# %matplotlib inline
import matplotlib.pyplot as plt
# missing line
from scipy.stats import norm
import numpy as np
plt.rcParams.update({"axes.grid":True,"grid.color":"black","grid.alpha":"0.25","grid.linestyle":"--"})
plt.rcParams.update({'font.size': 14})

import ipywidgets as widgets # For interactive plots/buttons

# b. plotting figure
def fitting_normal(X,mu_guess,sigma_guess):
    
    # i. normal distribution from guess
    F = norm(loc=mu_guess,scale=sigma_guess)
    
    # ii. x-values
    # missing line, x_low =
    x_low = F.ppf(0.001)
    #gemmer nederste x værdi som der hvor fordelingens CDF er 0.001
    # missing line, x_high = 
    x_high = F.ppf(0.999)
    #gemmer øverste x værdi som der hvor fordelingens CDF er 0.999
    x = np.linspace(x_low,x_high,100)

    # iii. figure
    fig = plt.figure(dpi=100)
    ax = fig.add_subplot(1,1,1)
    ax.plot(x,F.pdf(x),lw=2)
    #CHR: The lw=2 argument sets the linewidth of the plotted line to 2 units.
    ax.hist(X,bins=100,density=True,histtype='stepfilled');
    #CHR: note the normal distribution takes from the x, where we have
    # our guess distribution, but our histogram is taking from X,
    # where we have our real distribution
    ax.set_ylim([0,0.5])
    ax.set_xlim([-6,6])
    #CHR:set limits for axis

# c. parameters
mu_true = 2
sigma_true = 1
mu_guess = 1
sigma_guess = 2

# d. random draws
X = np.random.normal(loc=mu_true,scale=sigma_true,size=10**6)

# e. figure
try:
    fitting_normal(X,mu_guess,sigma_guess)
except:
    print('failed')

# %% [markdown]
# **Second task:** Create an interactive version of the figure with sliders for $\mu$ and $\sigma$.

# %%
# write your code here
widgets.interact(fitting_normal,
                 X=widgets.fixed(X),
                 mu_guess = widgets.FloatSlider(description = r"mu", min = 0.1, max=5, step=0.05, value=2),
                 sigma_guess = widgets.FloatSlider(description=r"sigma", min=0.1, max=5, step =0.05,value = 1)
                 )
# Out:
# interactive(children=(FloatSlider(value=2.0, description='mu', max=5.0, min=0.1, step=0.05), FloatSlider(value…
# <function __main__.fitting_normal(X, mu_guess, sigma_guess)>

# %% [markdown]
# **Answer:**

# %% [markdown]
# See A3.py

# %% [markdown]
# ## Modules

# %% [markdown]
# 1. Call the function `myfun` from the module `mymodule` present in this folder.
# 2. Open VSCode and open the `mymodule.py`, add a new function and call it from this notebook.

# %%
# write your code here

from mymodule import *

myfun(1)
myfunfun()
# Out:
# hello world!
# jeg elsker python

# %% [markdown]
# **Answer:**

# %% [markdown]
# See A4.py

# %% [markdown]
# ## Git

# %% [markdown]
# 1. Try to go to your own personal GitHub main page and create a new repository. Then put your solution to this problem set in it.
# 2. Pair up with a fellow student. Clone each others repositories and run the code in them.

# %% [markdown]
# **IMPORTANT:** You will need **git** for the data project in a few needs. Better learn it know. Remember, that the teaching assistants are there to help you.

# %% [markdown]
# # Problem

# %% [markdown]
# Consider an **exchange economy** with
#
# 1. 2 goods, $(x_1,x_2)$
# 2. $N$ consumers indexed by $j \in \{1,2,\dots,N\}$
# 3. Preferences are Cobb-Douglas with truncated normally *heterogenous* coefficients
#
#     $$
#     \begin{aligned}
#     u^{j}(x_{1},x_{2}) & = x_{1}^{\alpha_{j}}x_{2}^{1-\alpha_{j}}\\
#      & \tilde{\alpha}_{j}\sim\mathcal{N}(\mu,\sigma)\\
#      & \alpha_j = \max(\underline{\mu},\min(\overline{\mu},\tilde{\alpha}_{j}))
#     \end{aligned}
#     $$
#
# 4. Endowments are *heterogenous* and given by
#
#     $$
#     \begin{aligned}
#     \boldsymbol{e}^{j}&=(e_{1}^{j},e_{2}^{j}) \\
#      &  & e_i^j \sim f, f(x,\beta_i) =  1/\beta_i \exp(-x/\beta)
#     \end{aligned}
#     $$

# %% [markdown]
# **Problem:** Write a function to solve for the equilibrium.

# %% [markdown]
# You can use the following parameters:

# %%
# a. parameters
N = 10000
mu = 0.5
sigma = 0.2
mu_low = 0.1
mu_high = 0.9
beta1 = 1.3
beta2 = 2.1
seed = 1986

# b. draws of random numbers
np.random.seed(seed)

#alphas
alpha_tilde=np.random.normal(loc=mu,scale=sigma, size = N)
alpha=np.fmax(mu_low,np.fmin(mu_high,alpha_tilde))
#CHR: fmax function returns the maximum non-NaN value.

#endowments
e1=np.random.exponential(scale=beta1, size=N)
e2=np.random.exponential(scale=beta2, size=N)


# c. demand function

#CHR: vi har cobb-douglas præferencer -> kender løsningen.

def demand_good_1_func(alpha, p1,p2,e1,e2):
    I = p1*e1+p2*e2
    #CHR: budgetconstraint.
    return alpha*I/p1
    #CHR: cobb-douglas standardløsning til gode 1



# d. excess demand function

def excess_demand_good_1_func(alpha,p1,p2,e1,e2):

    #demand
    demand = np.sum(demand_good_1_func(alpha,p1,p2,e1,e2))
    
    #supply
    supply = np.sum(e1)

    #excess demand
    excess_demand = demand-supply

    return excess_demand

# e. find equilibrium function

def find_equilibrium(alpha, p1, p2, e1, e2, kappa = 0.5, eps=1e-8,maxiter=500):
    t = 0
    while True:

        # a. step 1: excess demand
        Z1 = excess_demand_good_1_func(alpha,p1,p2,e1,e2)
        
        # b: step 2: stop?
        if  np.abs(Z1) < eps or t >= maxiter:
            print(f'{t:3d}: p1 = {p1:12.8f} -> excess demand -> {Z1:14.8f}')
            break    
    
        # c. step 3: update p1
        p1 = p1 + kappa*Z1/alpha.size
            
        # d. step 4: return 
        if t < 5 or t%25 == 0:
            print(f'{t:3d}: p1 = {p1:12.8f} -> excess demand -> {Z1:14.8f}')
        elif t == 5:
            print('   ...')
            
        t += 1    

    return p1

    
# f. call find equilibrium function
p1 = 1.4
p2 = 1
p1 = find_equilibrium(alpha, p1,p2,e1,e2, kappa=kappa, eps=eps)
# Out:
#   0: p1 =   1.45140633 -> excess demand ->  1028.12662815
#   1: p1 =   1.48943510 -> excess demand ->   760.57530384
#   2: p1 =   1.51816180 -> excess demand ->   574.53408777
#   3: p1 =   1.54017076 -> excess demand ->   440.17912761
#   4: p1 =   1.55720246 -> excess demand ->   340.63398830
#    ...
#  25: p1 =   1.62002594 -> excess demand ->     2.71044780
#  50: p1 =   1.62056127 -> excess demand ->     0.00980814
#  75: p1 =   1.62056320 -> excess demand ->     0.00003553
# 100: p1 =   1.62056321 -> excess demand ->     0.00000013
# 112: p1 =   1.62056321 -> excess demand ->     0.00000001

# %% [markdown]
# **Hint:** The code structure is exactly the same as for the exchange economy considered in the lecture. The code for solving that exchange economy is reproduced in condensed form below.

# %%
# a. parameters
N = 1000
k = 2
mu_low = 0.1
mu_high = 0.9
seed = 1986

# b. draws of random numbers
np.random.seed(seed)
alphas = np.random.uniform(low=mu_low,high=mu_high,size=N)

# c. demand function
def demand_good_1_func(alpha,p1,p2,k):
    I = k*p1+p2
    return alpha*I/p1

# d. excess demand function
def excess_demand_good_1_func(alphas,p1,p2,k):
    
    # a. demand
    demand = np.sum(demand_good_1_func(alphas,p1,p2,k))
    
    # b. supply
    supply = k*alphas.size
    
    # c. excess demand
    excess_demand = demand-supply
    
    return excess_demand

# e. find equilibrium function
def find_equilibrium(alphas,p1,p2,k,kappa=0.5,eps=1e-8,maxiter=500):
    
    t = 0
    while True:

        # a. step 1: excess demand
        Z1 = excess_demand_good_1_func(alphas,p1,p2,k)
        
        # b: step 2: stop?
        if  np.abs(Z1) < eps or t >= maxiter:
            print(f'{t:3d}: p1 = {p1:12.8f} -> excess demand -> {Z1:14.8f}')
            break    
    
        # c. step 3: update p1
        p1 = p1 + kappa*Z1/alphas.size
            
        # d. step 4: return 
        if t < 5 or t%25 == 0:
            print(f'{t:3d}: p1 = {p1:12.8f} -> excess demand -> {Z1:14.8f}')
        elif t == 5:
            print('   ...')
            
        t += 1    

    return p1

# e. call find equilibrium function
p1 = 1.4
p2 = 1
kappa = 0.1
eps = 1e-8
p1 = find_equilibrium(alphas,p1,p2,k,kappa=kappa,eps=eps)

# %% [markdown]
# **Answers:**

# %% [markdown]
# See A5.py

# %% [markdown]
# ## Save and load

# %% [markdown]
# Consider the code below and fill in the missing lines so the code can run without any errors.

# %%
import pickle

# a. create some data
my_data = {}
my_data['A'] = {'a':1,'b':2}
my_data['B'] = np.array([1,2,3])
# missing line
my_data['C'] = (3, 4, 5)


my_np_data = {}
my_np_data['D'] = np.array([1,2,3])
my_np_data['E'] = np.zeros((5,8))
# missing line
my_np_data['F'] = np.ones((5,5))

# c. save with pickle
with open(f'data.p', 'wb') as f:
    # missing line
    pickle.dump(my_data,f)
    
# d. save with numpy
# missing line, np.savez(?)
np.savez(f'data.pnz',**my_np_data)
    
# a. try
def load_all():
    with open(f'data.p', 'rb') as f:
        data = pickle.load(f)
        A = data['A']
        B = data['B']
        C = data['C']

    with np.load(f'data.npz') as data:
        D = data['D']
        E = data['E']
        F = data['F']        
    
    print('variables loaded without error')
    
try:
    load_all()
except:
    print('failed')
# Out:
# variables loaded without error

# %% [markdown]
# **Answer:**

# %% [markdown]
# See A6.py

# %% [markdown]
# # Extra Problems

# %% [markdown]
# ## Multiple goods

# %% [markdown]
# Solve the main problem extended with multiple goods:

# %% [markdown]
# $$
# \begin{aligned}
# u^{j}(x_{1},x_{2}) & = x_{1}^{\alpha^1_{j}} \cdot x_{2}^{\alpha^2_{j}} \cdots x_{M}^{\alpha^M_{j}}\\
#  &  \alpha_j = [\alpha^1_{j},\alpha^2_{j},\dots,\alpha^M_{j}] \\
#  &  \log(\alpha_j) \sim \mathcal{N}(0,\Sigma) \\
# \end{aligned}
# $$
#
# where $\Sigma$ is a valid covariance matrix.

# %%
# a. choose parameters
N = 10000
J = 3

# b. choose Sigma
Sigma_lower = np.array([[1, 0, 0], [0.5, 1, 0], [0.25, -0.5, 1]])
Sigma_upper = Sigma_lower.T
Sigma = Sigma_upper@Sigma_lower
print(Sigma)

# c. draw random numbers
alphas = np.exp(np.random.multivariate_normal(np.zeros(J), Sigma, 10000))
print(np.mean(alphas,axis=0))
print(np.corrcoef(alphas.T))

# write your code here
